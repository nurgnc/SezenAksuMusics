# %%
from bs4 import BeautifulSoup as bs
import requests
import json
from flask import Flask
from flask_cors import CORS
from flask import jsonify
from threading import Thread
import sqlite3

# %%
url = "https://www.youtube.com/playlist?list=PLEwmXfTz7jDynzZKZzpx8sdKjnWuLQAW3"

# %%
from selenium import webdriver
opts = webdriver.FirefoxOptions()
opts.headless = False
browser = webdriver.Firefox(executable_path=r'geckodriver.exe',options=opts)
browser.get(url)

# %%
songs = browser.find_elements_by_tag_name("ytd-playlist-video-renderer")

# %%
len(songs)
song_list = []

# %%
conn = sqlite3.connect('playlist.db')
c = conn.cursor()
c.execute('CREATE TABLE if not exists songs (id int primary key,song_name varchar(100),singer varchar(50),song_yt_url varchar(20))')
for song in songs:
    data = song.find_element_by_tag_name('h3')
    link = data.find_element_by_tag_name('a').get_attribute('href')
    title = data.find_element_by_tag_name('a').get_attribute('title')
    print(title)
    song = link.split("&")[0].split("=")[1]
    index = link.split("&")[2].split("=")[1]
    song_inf = title.split(' - ')
    if(len(song_inf)<2):
        temp = song_inf[0]
        song_inf[0] = "Sezen Aksu"
        song_inf.append(temp)
    song_list.append(song)
    query = "INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES ({},'{}','{}','{}')".format(index,song_inf[1].replace("'"," "),song_inf[0],song)
    print(query)
    c.execute(query)
    conn.commit()
# Out:
# Sezen Aksu - Yok ki
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (1,'Yok ki','Sezen Aksu','h0C5TpH-A1I')
# Sezen Aksu - Ben De Yoluma Giderim (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (2,'Ben De Yoluma Giderim (Official Video)','Sezen Aksu','p4yxn8ZahPI')
# Sezen Aksu - Vazgeçtim (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (3,'Vazgeçtim (Lyrics | Şarkı Sözleri)','Sezen Aksu','TGHOcyiZrDs')
# Sezen Aksu - Biliyorsun (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (4,'Biliyorsun (Official Audio)','Sezen Aksu','-aW8x1jTA2U')
# Sezen Aksu - Tükeneceğiz (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (5,'Tükeneceğiz (Official Audio)','Sezen Aksu','Eg6gKLXA30U')
# Sezen Aksu -  Sen Ağlama (Lyrics I Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (6,' Sen Ağlama (Lyrics I Şarkı Sözleri)','Sezen Aksu','llflkaAP0vQ')
# Sezen Aksu - Kaçın Kurası (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (7,'Kaçın Kurası (Official Audio)','Sezen Aksu','352QSI4nsQk')
# Sezen Aksu - Tutuklu (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (8,'Tutuklu (Official Video)','Sezen Aksu','fEdZGZpAZZk')
# Sezen Aksu - Yansın İstanbul
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (9,'Yansın İstanbul','Sezen Aksu','nUhlsec8uhs')
# Sezen Aksu - Belalım (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (10,'Belalım (Official Audio)','Sezen Aksu','TDoWaCaowMw')
# Sezen Aksu - Haydi Gel Benimle Ol (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (11,'Haydi Gel Benimle Ol (Official Audio)','Sezen Aksu','qol0bBbcm44')
# Sezen Aksu - Sen Ciddisin (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (12,'Sen Ciddisin (Official Video)','Sezen Aksu','2c__lhepTdA')
# Sezen Aksu - Her Şeyi Yak (Lyrics I Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (13,'Her Şeyi Yak (Lyrics I Şarkı Sözleri)','Sezen Aksu','0-DpSouDHU4')
# Sezen Aksu - Perişanım Şimdi (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (14,'Perişanım Şimdi (Official Video)','Sezen Aksu','SpeSzEhpLk8')
# Sezen Aksu - Yetinmeyi Bilir Misin? (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (15,'Yetinmeyi Bilir Misin? (Official Video)','Sezen Aksu','uVaG7dvT91s')
# Sezen Aksu - Son Bakış (Lyrics I Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (16,'Son Bakış (Lyrics I Şarkı Sözleri)','Sezen Aksu','UrlQ9AklZT8')
# Sezen Aksu - Manifesto (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (17,'Manifesto (Official Video)','Sezen Aksu','6ywcf07KQZA')
# Sezen Aksu - İnsanlık Hali (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (18,'İnsanlık Hali (Official Video)','Sezen Aksu','C6_Gtdi32Ek')
# Sezen Aksu - Kurşuni Renkler  (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (19,'Kurşuni Renkler  (Lyrics | Şarkı Sözleri)','Sezen Aksu','mRV8s7YJpCQ')
# Sezen Aksu - Rakkas (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (20,'Rakkas (Official Audio)','Sezen Aksu','LYDOlK-wSX0')
# Sezen Aksu - Kaybolan Yıllar (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (21,'Kaybolan Yıllar (Official Audio)','Sezen Aksu','H7mxXm0Avts')
# Sezen Aksu - Küçüğüm (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (22,'Küçüğüm (Lyrics | Şarkı Sözleri)','Sezen Aksu','ygotTM_4x-g')
# Sezen Aksu - Erkek Güzeli
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (23,'Erkek Güzeli','Sezen Aksu','rswJ1SiQ8sU')
# Sezen Aksu - Seni Yerler (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (24,'Seni Yerler (Official Video)','Sezen Aksu','IVE00F-2ZCw')
# Sezen Aksu - Yalnızca Sitem (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (25,'Yalnızca Sitem (Official Audio)','Sezen Aksu','g1vCetSh7js')
# Sezen Aksu - Unuttun Mu Beni (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (26,'Unuttun Mu Beni (Official Video)','Sezen Aksu','5k5P_Eqy4xo')
# Sezen Aksu - Farkındayım (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (27,'Farkındayım (Official Video)','Sezen Aksu','uTSYnM-UxD0')
# Sezen Aksu - Şanıma İnanma
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (28,'Şanıma İnanma','Sezen Aksu','nm93SFd4TqI')
# Sezen Aksu - Kaybedenler (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (29,'Kaybedenler (Official Video)','Sezen Aksu','wRWZeosgFgM')
# Sezen Aksu - Git (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (30,'Git (Official Video)','Sezen Aksu','rzhvo0PF74k')
# Sezen Aksu - Canımsın Sen (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (31,'Canımsın Sen (Official Audio)','Sezen Aksu','IRwvyl5aYIc')
# Sezen Aksu - Şinanay (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (32,'Şinanay (Official Video)','Sezen Aksu','O6CIRoPzcws')
# Sezen Aksu - Vay (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (33,'Vay (Official Video)','Sezen Aksu','TeH7sCVCMJk')
# Sezen Aksu - İhanetten Geri Kalan (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (34,'İhanetten Geri Kalan (Official Audio)','Sezen Aksu','D-i77gTIEWM')
# Sezen Aksu - Aşktan Ne Haber (Lyrics I Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (35,'Aşktan Ne Haber (Lyrics I Şarkı Sözleri)','Sezen Aksu','Fhzjkd_LBwU')
# Sezen Aksu - Gidemem (Lyrics I Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (36,'Gidemem (Lyrics I Şarkı Sözleri)','Sezen Aksu','vaXrcHa_gYU')
# Sezen Aksu - Karşıyım (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (37,'Karşıyım (Official Video)','Sezen Aksu','Wuk-PoBRW2E')
# Sezen Aksu - Geri Dön (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (38,'Geri Dön (Official Video)','Sezen Aksu','3_961n_y4TA')
# Sezen Aksu - Masum Değiliz (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (39,'Masum Değiliz (Official Video)','Sezen Aksu','Lc8Nuk2VN-I')
# Sezen Aksu - Keskin Bıçak (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (40,'Keskin Bıçak (Official Video)','Sezen Aksu','kR0EX8XK-8I')
# Sezen Aksu - Ben Her Bahar Aşık Olurum (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (41,'Ben Her Bahar Aşık Olurum (Official Video)','Sezen Aksu','vS0oVjcxC_o')
# Sezen Aksu - Unut | Kolay Olmayacak (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (42,'Unut | Kolay Olmayacak (Official Audio)','Sezen Aksu','LvNz1IIzPpI')
# Sezen Aksu - Sarı Odalar (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (43,'Sarı Odalar (Official Video)','Sezen Aksu','vjU-RcwSwO4')
# Sezen Aksu - Aldatıldık
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (44,'Aldatıldık','Sezen Aksu','9YcwFYrM0JM')
# Sezen Aksu - Begonvil
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (45,'Begonvil','Sezen Aksu','yJVFPENseck')
# Sezen Aksu - Kavaklar (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (46,'Kavaklar (Official Video)','Sezen Aksu','hy2X6cWi1Is')
# Sezen Aksu - Kutlama (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (47,'Kutlama (Official Audio)','Sezen Aksu','N3WhY5mTMXA')
# Sezen Aksu - Kendimce (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (48,'Kendimce (Official Video)','Sezen Aksu','Gx_VRdCgI-c')
# Sezen Aksu - Gidiyorum (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (49,'Gidiyorum (Official Video)','Sezen Aksu','C0EgvamXF9c')
# Sezen Aksu - İstanbul İstanbul Olalı (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (50,'İstanbul İstanbul Olalı (Lyrics | Şarkı Sözleri)','Sezen Aksu','m8PyoUy7YLI')
# Sezen Aksu - Kaç Yıl Geçti Aradan (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (51,'Kaç Yıl Geçti Aradan (Official Video)','Sezen Aksu','vpc7KnLcgxY')
# Sezen Aksu - Onu Alma Beni Al (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (52,'Onu Alma Beni Al (Official Video)','Sezen Aksu','XTNWD9FeZ20')
# Sezen Aksu - Seni Kimler Aldı (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (53,'Seni Kimler Aldı (Official Audio)','Sezen Aksu','VuNrNXQzUuo')
# Sezen Aksu - Tutsak (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (54,'Tutsak (Official Video)','Sezen Aksu','H0e5vRbkhpw')
# Sezen Aksu - Geçer
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (55,'Geçer','Sezen Aksu','q92L5xu-xHw')
# Sezen Aksu - Herkes Yaralı
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (56,'Herkes Yaralı','Sezen Aksu','URdN70OKLLo')
# Sezen Aksu - Kusura Bakma - 45'lik (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (57,'Kusura Bakma','Sezen Aksu','2hPNYeXf-AY')
# Sezen Aksu - Hasret (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (58,'Hasret (Official Audio)','Sezen Aksu','KWaBVwT5B6g')
# Sezen Aksu - Firuze (Official Audio - Orijinal Plak Kayıt)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (59,'Firuze (Official Audio','Sezen Aksu','EO4r_SV6bbA')
# Sezen Aksu - Ne Ağlarsın (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (60,'Ne Ağlarsın (Official Audio)','Sezen Aksu','D6r5ZH9YXgE')
# Sezen Aksu - Gülümse (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (61,'Gülümse (Official Video)','Sezen Aksu','qgfLk8Uksxo')
# Sezen Aksu - Çocuklar Gibi (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (62,'Çocuklar Gibi (Official Audio)','Sezen Aksu','OZ-W9sKJKHg')
# Sezen Aksu - Köz (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (63,'Köz (Official Audio)','Sezen Aksu','FZODxoAwLoc')
# Sezen Aksu - Olmaz Olsun (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (64,'Olmaz Olsun (Official Audio)','Sezen Aksu','NpYvpOKrsUk')
# Sezen Aksu - İki Gözüm (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (65,'İki Gözüm (Official Audio)','Sezen Aksu','hAfLPFIbi0A')
# Sezen Aksu - Hoş Geldin (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (66,'Hoş Geldin (Lyrics | Şarkı Sözleri)','Sezen Aksu','LkBJja_QdWc')
# Sezen Aksu - Ne Kavgam Bitti Ne Sevdam (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (67,'Ne Kavgam Bitti Ne Sevdam (Official Audio)','Sezen Aksu','fkMHS-49ar8')
# Sezen Aksu - Beni Unutma (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (68,'Beni Unutma (Official Video)','Sezen Aksu','EsZTne6WEQE')
# Sezen Aksu - Acıtmışım Canını Sevdikçe (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (69,'Acıtmışım Canını Sevdikçe (Official Audio)','Sezen Aksu','gQQET1i38KQ')
# Sezen Aksu - İkili Delilik - Kivanch K., Cem Oyal Remix  (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (70,'İkili Delilik','Sezen Aksu','zNg7PdppImA')
# Sezen Aksu - Değer Mi? (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (71,'Değer Mi? (Official Video)','Sezen Aksu','Gi-K-ER823c')
# Sezen Aksu - Bir Çocuk Sevdim (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (72,'Bir Çocuk Sevdim (Official Audio)','Sezen Aksu','eoOZj7CYmL0')
# Rubato & Simge - Yalnızca Sitem
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (73,'Yalnızca Sitem','Rubato & Simge','gQ3E5tDu2t0')
# Sezen Aksu - Deli Kızın Türküsü (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (74,'Deli Kızın Türküsü (Official Video)','Sezen Aksu','8SadbBESMbM')
# Sezen Aksu - Güvercin (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (75,'Güvercin (Official Audio)','Sezen Aksu','-2mcvqv9lCk')
# Sezen Aksu - Ah Beni Beni
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (76,'Ah Beni Beni','Sezen Aksu','sKqOHTzJATY')
# Sezen Aksu - Hadi Bakalım (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (77,'Hadi Bakalım (Official Video)','Sezen Aksu','KSlOGG5Ohgg')
# Sezen Aksu - Kalp Unutmaz (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (78,'Kalp Unutmaz (Lyrics | Şarkı Sözleri)','Sezen Aksu','lf1MnMGWRlQ')
# Sezen Aksu - Benim Karanlık Yanım (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (79,'Benim Karanlık Yanım (Official Audio)','Sezen Aksu','baVnsJhAcBM')
# Sezen Aksu - Ünzile (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (80,'Ünzile (Official Audio)','Sezen Aksu','AXpgWAZHVls')
# Sezen Aksu - Onursuz Olmasın Aşk (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (81,'Onursuz Olmasın Aşk (Official Audio)','Sezen Aksu','52shmmb40dM')
# Sezen Aksu - Yol Arkadaşım (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (82,'Yol Arkadaşım (Official Audio)','Sezen Aksu','7HfrxlYl3cQ')
# Sezen Aksu - Zalim (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (83,'Zalim (Official Audio)','Sezen Aksu','R0KCc9-0i6E')
# Sezen Aksu - Kime Kalmış Bu Dünya (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (84,'Kime Kalmış Bu Dünya (Official Audio)','Sezen Aksu','DSpQZIwazNc')
# Sezen Aksu - Kaçak (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (85,'Kaçak (Official Audio)','Sezen Aksu','CMVtuabMeGc')
# Sezen Aksu - El Gibi (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (86,'El Gibi (Official Video)','Sezen Aksu','QLGs8GL4QaE')
# Sezen Aksu İzmir'in kızları klibi
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (87,'Sezen Aksu İzmir in kızları klibi','Sezen Aksu','w1t8q6_Ophg')
# Sezen Aksu - Hata (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (88,'Hata (Official Audio)','Sezen Aksu','X6gf7-oS5xU')
# Sezen Aksu - Hayat Sana Teşekkür Ederim (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (89,'Hayat Sana Teşekkür Ederim (Lyrics | Şarkı Sözleri)','Sezen Aksu','VgTZSmjX7P8')
# Sezen Aksu - Seni İstiyorum (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (90,'Seni İstiyorum (Lyrics | Şarkı Sözleri)','Sezen Aksu','dKVgKwWNSSE')
# Sezen Aksu - Konduramadım (Ozan Bayraşa Rework) ft. Okay Barış
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (91,'Konduramadım (Ozan Bayraşa Rework) ft. Okay Barış','Sezen Aksu','GVWhtMQvNkc')
# ROYAL PHILARMONIC ORCHESTRAS-KAÇIN KURASI
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (92,'ROYAL PHILARMONIC ORCHESTRAS-KAÇIN KURASI','Sezen Aksu','vTAEq815Ypg')
# Sezen Aksu - Yanmışım Sönmüşüm Ben (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (93,'Yanmışım Sönmüşüm Ben (Official Video)','Sezen Aksu','-944bPFPRFs')
# Sezen Aksu - Bir Kuş Uçur (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (94,'Bir Kuş Uçur (Official Audio)','Sezen Aksu','Q1rH03ijFjY')
# Sezen Aksu - Bile Bile (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (95,'Bile Bile (Official Video)','Sezen Aksu','mOBNFdggNuE')
# Sezen Aksu - Büklüm Büklüm (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (96,'Büklüm Büklüm (Official Audio)','Sezen Aksu','1vj5MM9-ncI')
# Sezen Aksu - Kahpe Kader (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (97,'Kahpe Kader (Official Audio)','Sezen Aksu','eMKWBksJy1c')
# Sezen Aksu "Dön" (18.07.2012 - Harbiye Cemil Topuzlu Açık Hava Tiyatrosu)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (98,'Harbiye Cemil Topuzlu Açık Hava Tiyatrosu)','Sezen Aksu "Dön" (18.07.2012','8HWRVPHq_c0')
# Sezen Aksu - Eskidendi, Çok Eskiden (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (99,'Eskidendi, Çok Eskiden (Official Video)','Sezen Aksu','wJqVkwMkLkk')
# Sezen Aksu - Yarası Saklım (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (100,'Yarası Saklım (Official Video)','Sezen Aksu','0QjiVbksMEU')
# Sezen Aksu - Bırak Beni (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (101,'Bırak Beni (Official Video)','Sezen Aksu','Fjx4Enb1w3g')
# Sezen Aksu - Yalnızlık Senfonisi (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (102,'Yalnızlık Senfonisi (Official Audio)','Sezen Aksu','kRcITnEyRiM')
# Ben öyle birini sevdim ki- أنا أحببت شخصاً-sezen aksu -مترجمة للعربية
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (103,'Ben öyle birini sevdim ki- أنا أحببت شخصاً-sezen aksu -مترجمة للعربية','Sezen Aksu','aMwcXJOA64A')
# Sezen Aksu - Gidiyorum Bu Şehirden (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (104,'Gidiyorum Bu Şehirden (Official Audio)','Sezen Aksu','Y74uukUiCoM')
# Erol Evgin & Sezen Aksu - Ben İmkansız Aşklar İçin Yaratılmışım (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (105,'Ben İmkansız Aşklar İçin Yaratılmışım (Official Audio)','Erol Evgin & Sezen Aksu','AyK2mn9L39U')
# Sezen Aksu - Bu Gece (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (106,'Bu Gece (Official Audio)','Sezen Aksu','0O2ft0ZuEHU')
# Sezen Aksu - Kalbim Ege'de Kaldı (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (107,'Kalbim Ege de Kaldı (Official Video)','Sezen Aksu','rb9iUUHXsyI')
# Sezen Aksu - Ne Yapayım Şimdi Ben? (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (108,'Ne Yapayım Şimdi Ben? (Official Video)','Sezen Aksu','kYxr7SLY2R0')
# Sezen Aksu - Her Şey Fani
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (109,'Her Şey Fani','Sezen Aksu','yykHOIvO4to')
# Sezen Aksu - Bekle
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (110,'Bekle','Sezen Aksu','rG_idC9Tcb4')
# Sezen Aksu - Unutamam (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (111,'Unutamam (Official Audio)','Sezen Aksu','1E2AO1BHd3k')
# Sezen Aksu - İçime Sinmiyor (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (112,'İçime Sinmiyor (Official Audio)','Sezen Aksu','Ky2A1LFIoao')
# Sezen Aksu - Hala Haber Bekliyorum Senden (Lyrics I Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (113,'Hala Haber Bekliyorum Senden (Lyrics I Şarkı Sözleri)','Sezen Aksu','b4muEWcJxdY')
# Sezen Aksu - İki Delilik
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (114,'İki Delilik','Sezen Aksu','a2sUqQx1p2A')
# Sezen Aksu - İkinci Bahar (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (115,'İkinci Bahar (Official Audio)','Sezen Aksu','Vo6sdlOLHhI')
# Sezen Aksu - Rüzgar Kırdı Dalımı
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (116,'Rüzgar Kırdı Dalımı','Sezen Aksu','80yV7JYgoEE')
# Sezen Aksu - Sultan Süleyman (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (117,'Sultan Süleyman (Official Video)','Sezen Aksu','89PepdEhKCM')
# Sezen Aksu - La'l (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (118,'La l (Lyrics | Şarkı Sözleri)','Sezen Aksu','h7g66YD6D8U')
# Sezen Aksu - Söz Bitti
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (119,'Söz Bitti','Sezen Aksu','VrMyCnXZYYY')
# Sezen Aksu - Sorma (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (120,'Sorma (Official Audio)','Sezen Aksu','rNhAHqpp6_g')
# Hepsi Tempo (Logosuz)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (121,'Hepsi Tempo (Logosuz)','Sezen Aksu','mg3v-ll7W6A')
# Sezen Aksu - Sızı (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (122,'Sızı (Official Audio)','Sezen Aksu','sAsC6Ozru_4')
# Sezen Aksu - Ruhuma Asla (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (123,'Ruhuma Asla (Official Video)','Sezen Aksu','1EjFP2rBy5Q')
# Sezen Aksu -  Sayım (Lyrics I Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (124,' Sayım (Lyrics I Şarkı Sözleri)','Sezen Aksu','q_gLybnREFM')
# Sezen Aksu - Sarışın (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (125,'Sarışın (Official Video)','Sezen Aksu','e_9IJM3N9XM')
# Sezen Aksu - Elveda (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (126,'Elveda (Lyrics | Şarkı Sözleri)','Sezen Aksu','WbFP1bVmEd0')
# Sezen Aksu - Akşam Güneşi - 2012 Orijinal Şarkı "Orhan Gencebay İle Bir Ömür"
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (127,'Akşam Güneşi','Sezen Aksu','DCz8WgbndXI')
# Masum Değiliz
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (128,'Masum Değiliz','Sezen Aksu','mXP_rt5KKwA')
# Sezen Aksu - Son Sardunyalar (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (129,'Son Sardunyalar (Official Audio)','Sezen Aksu','-_DMr-dlbXc')
# Sezen Aksu - Aşk (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (130,'Aşk (Official Audio)','Sezen Aksu','nOM73M0VIQ4')
# Sezen Aksu - Yaz I Akustik (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (131,'Yaz I Akustik (Official Audio)','Sezen Aksu','crw58VTZP2Q')
# Sezen Aksu - Delidir
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (132,'Delidir','Sezen Aksu','p0x6nZ27AXw')
# Sezen Aksu - Bir Zamanlar Deli Gönlüm (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (133,'Bir Zamanlar Deli Gönlüm (Official Audio)','Sezen Aksu','lp_w2890n7Q')
# Sezen Aksu - Yeni ve Yeni Kalanlar (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (134,'Yeni ve Yeni Kalanlar (Official Video)','Sezen Aksu','1XNjqQILBMw')
# Sezen Aksu - Ben Kedim Yatağım (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (135,'Ben Kedim Yatağım (Official Audio)','Sezen Aksu','Va942t-KCFU')
# Sezen Aksu - Yine mi Çiçek (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (136,'Yine mi Çiçek (Official Audio)','Sezen Aksu','Pzsg2WSrkmE')
# Sezen Aksu - Ah Mazi (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (137,'Ah Mazi (Official Video)','Sezen Aksu','1rIu_6tYC64')
# Sezen Aksu - Uslanmadım
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (138,'Uslanmadım','Sezen Aksu','DU21wq1K5XE')
# Sezen Aksu - Dua (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (139,'Dua (Official Audio)','Sezen Aksu','fv5ZRi6WVTw')
# Sezen Aksu - Anlasana
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (140,'Anlasana','Sezen Aksu','Cx40AssrgUo')
# dj haribo sezen aksu ben sende tutuklu kaldım remix
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (141,'dj haribo sezen aksu ben sende tutuklu kaldım remix','Sezen Aksu','4lCC68MiSj4')
# Sezen Aksu - Kınalı Kuzum (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (142,'Kınalı Kuzum (Lyrics | Şarkı Sözleri)','Sezen Aksu','iGFRQeb_tiE')
# Sezen Aksu - Şu Saniye (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (143,'Şu Saniye (Official Audio)','Sezen Aksu','p7MCq0kbntM')
# Sezen Aksu - Minik Serçe (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (144,'Minik Serçe (Official Audio)','Sezen Aksu','sGbxvhgmbqo')
# Sezen Aksu - Yaşanmamış Yıllar - 45'lik (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (145,'Yaşanmamış Yıllar','Sezen Aksu','Yx-7dTQ8uQE')
# Sezen Aksu - Hu Hu (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (146,'Hu Hu (Official Audio)','Sezen Aksu','rK_Rbry0Nuw')
# Sezen Aksu - Yeter (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (147,'Yeter (Official Audio)','Sezen Aksu','C9rLaC71Yx8')
# Sezen Aksu - Oh Oh (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (148,'Oh Oh (Official Video)','Sezen Aksu','Jmr0DcR3BV4')
# Sezen Aksu - Ağlamak Güzeldir
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (149,'Ağlamak Güzeldir','Sezen Aksu','_UNNRcnKGsw')
# Sezen Aksu - Dağlar Dağlar (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (150,'Dağlar Dağlar (Official Audio)','Sezen Aksu','DgJWuhrv3ZQ')
# Sezen Aksu - Şarkı Söylemek Lazım (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (151,'Şarkı Söylemek Lazım (Lyrics | Şarkı Sözleri)','Sezen Aksu','sXUYCIDsu44')
# Sezen Aksu - Köprü (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (152,'Köprü (Official Audio)','Sezen Aksu','GZPHbb3_-v4')
# Sezen Aksu - Yalnız Kullar (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (153,'Yalnız Kullar (Official Audio)','Sezen Aksu','QkM8rYjGJl0')
# Sezen Aksu - Ahbap Çavuşlar
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (154,'Ahbap Çavuşlar','Sezen Aksu','deScooa3lGo')
# Sezen Aksu - Üfle de Söneyim (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (155,'Üfle de Söneyim (Official Audio)','Sezen Aksu','VZK6CO0RpaM')
# Sezen Aksu - Hadi Beni Yine Sev Yeniden SEV
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (156,'Hadi Beni Yine Sev Yeniden SEV','Sezen Aksu','GmwkWJgMHvM')
# Sezen Aksu - Hala Haber Bekliyorum Senden (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (157,'Hala Haber Bekliyorum Senden (Official Audio)','Sezen Aksu','K44eLQi5ocQ')
# Sezen Aksu - Namus (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (158,'Namus (Official Video)','Sezen Aksu','c1p3Qin-1kM')
# Sezen Aksu - Ben Annemi İsterim (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (159,'Ben Annemi İsterim (Official Audio)','Sezen Aksu','X8t7RatOIIs')
# Sezen Aksu - Adem Olan Anlar (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (160,'Adem Olan Anlar (Official Video)','Sezen Aksu','B1xAmM7rJnU')
# Sezen Aksu - Dansöz Dünya  (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (161,'Dansöz Dünya  (Lyrics | Şarkı Sözleri)','Sezen Aksu','Lv2jX3idgN4')
# Sezen Aksu - Takvim
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (162,'Takvim','Sezen Aksu','T1EEG-aw4UY')
# Sezen Aksu - Arkadaş Şarkısını Duyunca (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (163,'Arkadaş Şarkısını Duyunca (Official Audio)','Sezen Aksu','ZWy3jShruhU')
# Sezen Aksu - Kıran Kırana (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (164,'Kıran Kırana (Lyrics | Şarkı Sözleri)','Sezen Aksu','fRcGuPFeDeo')
# Sezen Aksu - Savaşma Seviş Benle (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (165,'Savaşma Seviş Benle (Lyrics | Şarkı Sözleri)','Sezen Aksu','EDumtKX2bxY')
# Sezen Aksu - İsyancı (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (166,'İsyancı (Official Audio)','Sezen Aksu','lGx9aWA2fKo')
# Sezen Aksu - Affet (Emir Köroğlu Remix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (167,'Affet (Emir Köroğlu Remix)','Sezen Aksu','XrpMf0b_Edc')
# Sezen Aksu -  Yol Bitti Çoktan
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (168,' Yol Bitti Çoktan','Sezen Aksu','efT5n8BVrK4')
# Sezen Aksu - Kış Masalı (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (169,'Kış Masalı (Official Audio)','Sezen Aksu','B02IfgIgrWc')
# Sezen Aksu - Seni Gidi Vurdum Duymaz (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (170,'Seni Gidi Vurdum Duymaz (Official Video)','Sezen Aksu','wGfV62MPqYg')
# Sezen Aksu - Alaturka (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (171,'Alaturka (Official Audio)','Sezen Aksu','1FcarZvvmDw')
# Sezen Aksu - Aşkları da Vururlar (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (172,'Aşkları da Vururlar (Lyrics | Şarkı Sözleri)','Sezen Aksu','jrZ_o8bDqRg')
# Sezen Aksu - Gitme Kal Bu Şehirde
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (173,'Gitme Kal Bu Şehirde','Sezen Aksu','8bB_4BmLiEs')
# Sezen Aksu - Homini Pufidi Tumba (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (174,'Homini Pufidi Tumba (Official Video)','Sezen Aksu','EsjOV8hQ7Xo')
# Sezen Aksu - Hakkımda Konuşmuşsun (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (175,'Hakkımda Konuşmuşsun (Official Audio)','Sezen Aksu','T8QPkVxDZWQ')
# Sezen Aksu - Deli Gönlüm (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (176,'Deli Gönlüm (Lyrics | Şarkı Sözleri)','Sezen Aksu','hQu5exZOPOw')
# Sezen Aksu - Sen (Orjinal Plak Kayıt)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (177,'Sen (Orjinal Plak Kayıt)','Sezen Aksu','33YxKtFd2Vo')
# Sezen Aksu - Bir Vurgun Bu Sevda [ Attila Özdemiroğlu Besteleri 2020 Arda Müzik ]
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (178,'Bir Vurgun Bu Sevda [ Attila Özdemiroğlu Besteleri 2020 Arda Müzik ]','Sezen Aksu','hg0RHvNOvRg')
# Sezen Aksu - Düş Bahçeleri (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (179,'Düş Bahçeleri (Official Audio)','Sezen Aksu','DXmOQuAq2SY')
# Sezen Aksu - Günaydın Memur Bey (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (180,'Günaydın Memur Bey (Official Audio)','Sezen Aksu','QOZvjgEsG70')
# Sezen Aksu - Dört Günlük Bir Şey (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (181,'Dört Günlük Bir Şey (Lyrics | Şarkı Sözleri)','Sezen Aksu','1XsLm_asa04')
# Sezen Aksu - Oldu Mu? (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (182,'Oldu Mu? (Official Video)','Sezen Aksu','S8VxBxrBaJk')
# Sad Oriental Turkish Rap Beat(Prod by Sero)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (183,'Sad Oriental Turkish Rap Beat(Prod by Sero)','Sezen Aksu','MaLNAZzfW3w')
# Sezen Aksu - Koca Kıçlı  (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (184,'Koca Kıçlı  (Official Audio)','Sezen Aksu','hTH0NKpgA7A')
# Sezen Aksu - O Sensin (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (185,'O Sensin (Lyrics | Şarkı Sözleri)','Sezen Aksu','vzmiG_z2_OY')
# Sezen Aksu - Roman (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (186,'Roman (Official Audio)','Sezen Aksu','VphEAUZ2ogY')
# Hepsi Senin Mi
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (187,'Hepsi Senin Mi','Sezen Aksu','iN9GqP0PvNc')
# Sezen Aksu - Baba Evi  (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (188,'Baba Evi  (Official Audio)','Sezen Aksu','Je0d0X6LGn8')
# Sezen Aksu - Pişman Olduğun Zaman
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (189,'Pişman Olduğun Zaman','Sezen Aksu','QsNKvMpoLf0')
# SEZEN AKSU,PETRO, RULA & PANCO (Beni yak herşeyi yak / Mia pista apo bosporo)"neşemore".mpg
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (190,'SEZEN AKSU,PETRO, RULA & PANCO (Beni yak herşeyi yak / Mia pista apo bosporo)"neşemore".mpg','Sezen Aksu','ppoVoEXP-RA')
# Sezen Aksu - Erkekler (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (191,'Erkekler (Official Video)','Sezen Aksu','ym5uQOWL2bQ')
# Sezen Aksu "Denge" (18.07.2008 - Harbiye Açık Hava Tiyatrosu)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (192,'Harbiye Açık Hava Tiyatrosu)','Sezen Aksu "Denge" (18.07.2008','2bY1aX3CGIM')
# Sezen Aksu - Helal Ettim Hakkımı (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (193,'Helal Ettim Hakkımı (Official Audio)','Sezen Aksu','otLYS05byIw')
# Sezen Aksu - Lale Devri (Lyrics I Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (194,'Lale Devri (Lyrics I Şarkı Sözleri)','Sezen Aksu','76SuDqOS8sk')
# Sezen Aksu - Gözlerine Göz Değmiş (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (195,'Gözlerine Göz Değmiş (Official Audio)','Sezen Aksu','lZEbKWOZkYw')
# Keskin Bıçak
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (196,'Keskin Bıçak','Sezen Aksu','FtPosh3y-Hk')
# SEZEN AKSU KADERİM 2015 HD KLİP by MELEKLERerkekOLUR
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (197,'SEZEN AKSU KADERİM 2015 HD KLİP by MELEKLERerkekOLUR','Sezen Aksu','L-zpVXSd7lM')
# Umut Akyürek £££ GEL GEL SARIŞINIM GEL
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (198,'Umut Akyürek £££ GEL GEL SARIŞINIM GEL','Sezen Aksu','WXz6jGw0WhQ')
# Sezen Aksu & The Royal Philharmonic Orchestra - "Hayat Sana Teşekkür Ederim" (11.12.2015- Zorlu PSM)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (199,'"Hayat Sana Teşekkür Ederim" (11.12.2015- Zorlu PSM)','Sezen Aksu & The Royal Philharmonic Orchestra','h1gOL8Ywq4A')
# Sezen Aksu - Kolay Değil (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (200,'Kolay Değil (Official Audio)','Sezen Aksu','lqi0wN6SbzQ')
# Sezen Aksu - Gidiyorum Bu Şehirden (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (201,'Gidiyorum Bu Şehirden (Official Video)','Sezen Aksu','DxBUrIRvOOc')
# hazan-ölürüm yoluna
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (202,'hazan-ölürüm yoluna','Sezen Aksu','eEhBJj-3eDY')
# Sezen Aksu - Hükümsüz (Remix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (203,'Hükümsüz (Remix)','Sezen Aksu','P8MHI67IUcA')
# Sezen Aksu - Tanrı İstemezse (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (204,'Tanrı İstemezse (Lyrics | Şarkı Sözleri)','Sezen Aksu','i_wegW9g5KM')
# Sezen Aksu "Ayar" (17.05.2011 - Kral TV Müzik Ödülleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (205,'Kral TV Müzik Ödülleri)','Sezen Aksu "Ayar" (17.05.2011','c6W8uYeUQ9k')
# Deli Kizin Türküsü
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (206,'Deli Kizin Türküsü','Sezen Aksu','rPsujjnRdtI')
# Sezen Aksu - Bindokuzyüzkırkbeş (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (207,'Bindokuzyüzkırkbeş (Official Audio)','Sezen Aksu','sZBM5iDvGZY')
# Sezen Aksu - İlk Gün Gibi - 45'lik (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (208,'İlk Gün Gibi','Sezen Aksu','zfwouHFDInQ')
# Sezen Aksu - Kördüğüm (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (209,'Kördüğüm (Official Audio)','Sezen Aksu','fCX6AFzSUho')
# Sezen Aksu - Bahane (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (210,'Bahane (Lyrics | Şarkı Sözleri)','Sezen Aksu','d5EpsNDEAac')
# İstanbul İstanbul Olalı
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (211,'İstanbul İstanbul Olalı','Sezen Aksu','HiXXmP8fXEY')
# Sezen Aksu - Sigaramın Dumanına Sarsam
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (212,'Sigaramın Dumanına Sarsam','Sezen Aksu','D2Uro0yaovU')
# Sezen Aksu - Yeniliğe Doğru (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (213,'Yeniliğe Doğru (Official Audio)','Sezen Aksu','JnMO4cvuQlM')
# Sezen Aksu - Kalaşnikof (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (214,'Kalaşnikof (Official Video)','Sezen Aksu','TdQqy6RVTV8')
# Sezen Aksu - Ey Benim Çocukluğum (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (215,'Ey Benim Çocukluğum (Official Audio)','Sezen Aksu','kkMTykQG4Qc')
# Sezen Aksu - Zor Yıllar (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (216,'Zor Yıllar (Official Audio)','Sezen Aksu','XoH44MGX7O4')
# Sezen Aksu - Akasyalar Açarken (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (217,'Akasyalar Açarken (Official Audio)','Sezen Aksu','hVyG4gwLGZc')
# Sezen Aksu - Ahdım Olsun
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (218,'Ahdım Olsun','Sezen Aksu','f8Mtad-q5Xs')
# Sezen Aksu - Kayıp Şehir
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (219,'Kayıp Şehir','Sezen Aksu','YNNDarfjuSQ')
# Sezen Aksu - Beni Kategorize Etme (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (220,'Beni Kategorize Etme (Official Video)','Sezen Aksu','R9Dv0MVD7rg')
# Sezen Aksu - Sor Beni (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (221,'Sor Beni (Official Audio)','Sezen Aksu','pqs3dIV_QTk')
# Sezen Aksu - Silemezler Gönlümden (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (222,'Silemezler Gönlümden (Official Audio)','Sezen Aksu','GIZWxIuWjmQ')
# Sezen Aksu - Çile (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (223,'Çile (Lyrics | Şarkı Sözleri)','Sezen Aksu','pMDjDKfGHxU')
# Sezen Aksu - Hayır (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (224,'Hayır (Official Audio)','Sezen Aksu','dhJqjxKMiyM')
# Kardeş Türküler & Sezen Aksu - Sarışınım [Yeni Bir Gün © 2011 BGST Records]
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (225,'Sarışınım [Yeni Bir Gün © 2011 BGST Records]','Kardeş Türküler & Sezen Aksu','yyJiPpSr8ZY')
# Sezen Aksu - Tanrı Misafiri
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (226,'Tanrı Misafiri','Sezen Aksu','KN-nhcPkLd8')
# Sezen Aksu - Le Le Le (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (227,'Le Le Le (Official Audio)','Sezen Aksu','Pj4n6rnBqb4')
# Sezen Aksu - Sude (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (228,'Sude (Official Video)','Sezen Aksu','9PqARl5l7Q8')
# Sezen Aksu - Gölge Etme (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (229,'Gölge Etme (Official Audio)','Sezen Aksu','eW1XrsxIkU0')
# Sezen Aksu - İstanbul Hatırası (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (230,'İstanbul Hatırası (Official Video)','Sezen Aksu','swWzhJaBtpM')
# Sezen Aksu - Hıdrellez (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (231,'Hıdrellez (Official Video)','Sezen Aksu','jPs0g5xHUI0')
# Sezen Aksu - Yak Bir Sigara (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (232,'Yak Bir Sigara (Official Audio)','Sezen Aksu','evvyOpeTrFw')
# Sezen Aksu - Düşünce (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (233,'Düşünce (Official Audio)','Sezen Aksu','zvvaxL7YM5M')
# Çakkıdı
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (234,'Çakkıdı','Sezen Aksu','_uRKPlXiF0s')
# Sezen Aksu - Pardon (Live)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (235,'Pardon (Live)','Sezen Aksu','miSRWD3MSZk')
# Sezen Aksu - Allah'ın Varsa (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (236,'Allah ın Varsa (Official Video)','Sezen Aksu','1TYJNhsqNsc')
# Sezen Aksu - Ballı (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (237,'Ballı (Official Audio)','Sezen Aksu','HIQXqrHsJvc')
# Sezen Aksu - Bir Başka Aşk (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (238,'Bir Başka Aşk (Official Audio)','Sezen Aksu','_sY2rlz61-0')
# Sezen Aksu - Muhabbet Kuşları (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (239,'Muhabbet Kuşları (Lyrics | Şarkı Sözleri)','Sezen Aksu','Ga8Stree5kw')
# Sezen Aksu - La İlahe İllallah (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (240,'La İlahe İllallah (Official Audio)','Sezen Aksu','C32ZKPtZYqw')
# Sezen Aksu - Çakkıdı (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (241,'Çakkıdı (Official Audio)','Sezen Aksu','L9kUxKEK6XY')
# Sezen Aksu - Söyle Kimsin (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (242,'Söyle Kimsin (Official Audio)','Sezen Aksu','3wTVQWH_Yl8')
# Sezen Aksu - Gün Gelir (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (243,'Gün Gelir (Official Audio)','Sezen Aksu','1xlhoFaFQZY')
# Kalbim Ege'de Kaldı
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (244,'Kalbim Ege de Kaldı','Sezen Aksu','nnFJh7MVpnY')
# Sezen Aksu - Ah Felek Yordun Beni (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (245,'Ah Felek Yordun Beni (Official Audio)','Sezen Aksu','wpFmVYC5qkY')
# Sezen Aksu - İmkansızım
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (246,'İmkansızım','Sezen Aksu','cxtkpz3TNyY')
# Sezen Aksu - Su Gibi (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (247,'Su Gibi (Lyrics | Şarkı Sözleri)','Sezen Aksu','0JFIBxtQiQk')
# Sezen Aksu - Sır (Efsane kadın) KLİP
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (248,'Sır (Efsane kadın) KLİP','Sezen Aksu','dV5EugpN8Jc')
# Sezen Aksu - Aynalar (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (249,'Aynalar (Official Audio)','Sezen Aksu','8lf4v5u7oRU')
# Sezen Aksu - Karam - Minik Serçe 1978
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (250,'Karam','Sezen Aksu','IR041JFNrT8')
# Sezen Aksu - Göç (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (251,'Göç (Official Audio)','Sezen Aksu','ifbRuN8OeZw')
# Sezen Aksu - Gelen Gideni Aratır (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (252,'Gelen Gideni Aratır (Official Audio)','Sezen Aksu','nxD-R3YKMy4')
# Sezen Aksu - Hani (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (253,'Hani (Official Audio)','Sezen Aksu','Nxtm1rHi7M0')
# Sezen Aksu - Şöyle Yürekli Bir Sevda (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (254,'Şöyle Yürekli Bir Sevda (Official Audio)','Sezen Aksu','TCTNUCXUSV8')
# Sezen Aksu - Rumeli Havası (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (255,'Rumeli Havası (Official Audio)','Sezen Aksu','I9x9wjrID7I')
# Sezen Aksu - Tutunamadım
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (256,'Tutunamadım','Sezen Aksu','IqaFjKKyQVI')
# Sezen Aksu - Şen Şarkı (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (257,'Şen Şarkı (Lyrics | Şarkı Sözleri)','Sezen Aksu','gv2Q1v8PoPA')
# Sezen Aksu - Odalarda Işıksızım
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (258,'Odalarda Işıksızım','Sezen Aksu','35aDpLmjcq0')
# Sezen Aksu - Kasım Yağmurları (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (259,'Kasım Yağmurları (Official Audio)','Sezen Aksu','OM_Pl0QhFt4')
# Sezen Aksu - Ali (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (260,'Ali (Official Audio)','Sezen Aksu','Z4oAr4q6FpE')
# Sezen Aksu - Nihayet (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (261,'Nihayet (Lyrics | Şarkı Sözleri)','Sezen Aksu','P-X6Ht5hCc8')
# Sezen Aksu - "Ağladıkça" (27.04.2013 - TİM Show Center Trio Konseri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (262,'"Ağladıkça" (27.04.2013','Sezen Aksu','AGK_9trHAHk')
# Küçüğüm
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (263,'Küçüğüm','Sezen Aksu','x9hxlB3-Qn4')
# Sezen Aksu - Neye Yarar (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (264,'Neye Yarar (Official Audio)','Sezen Aksu','Zk7XTI8I9Yc')
# Sezen Aksu - Ayrılıklar Bitmez (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (265,'Ayrılıklar Bitmez (Official Audio)','Sezen Aksu','NA91QLtvS-k')
# Sezen Aksu - İzmir Yanıyor
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (266,'İzmir Yanıyor','Sezen Aksu','gsnJJ2DbqWo')
# Sezen Aksu - Yalancı - 45'lik (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (267,'Yalancı','Sezen Aksu','yW71WhBaXzc')
# Sezen Aksu - Bûkê | Türkiye Şarkıları - The Songs of Turkey (Live)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (268,'Bûkê | Türkiye Şarkıları','Sezen Aksu','NVNnEGRLyPI')
# Sezen Aksu - Sonbahar (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (269,'Sonbahar (Official Audio)','Sezen Aksu','7x0-phWAVqI')
# Sezen Aksu - Arka Sokaklar (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (270,'Arka Sokaklar (Official Audio)','Sezen Aksu','1a6hl6OqQkg')
# Masum Değiliz
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (271,'Masum Değiliz','Sezen Aksu','9imBFaWU4vg')
# Benim Meskenim Dağlardır
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (272,'Benim Meskenim Dağlardır','Sezen Aksu','BqdyWu7xl6s')
# Sezen Aksu - Sürüklüyorum Çaresizliğimi (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (273,'Sürüklüyorum Çaresizliğimi (Official Audio)','Sezen Aksu','kiDe5WT4Fa4')
# Sezen Aksu - Tanrı'nın Gözyaşları (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (274,'Tanrı nın Gözyaşları (Official Audio)','Sezen Aksu','EbNspK9_BlU')
# Sezen Aksu "Bindokuzyüzkırkbeş & Bir Çocuk Sevdim" (Türkiye Şarkıları 2002)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (275,'Sezen Aksu "Bindokuzyüzkırkbeş & Bir Çocuk Sevdim" (Türkiye Şarkıları 2002)','Sezen Aksu','iBIrhiYx23M')
# Sezen Aksu - Bir Acı Kahvenin (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (276,'Bir Acı Kahvenin (Official Audio)','Sezen Aksu','qTOQHvW_pcs')
# Sezen Aksu - Davet (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (277,'Davet (Official Audio)','Sezen Aksu','Z3Roc8TIIp8')
# Sezen Aksu - Var Git Turnam (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (278,'Var Git Turnam (Official Audio)','Sezen Aksu','GLxtjX8x3Ro')
# Sezen Aksu - Mia Pista Apo Fosforo & Her Şeyi Yak | Türkiye Şarkıları (Live)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (279,'Mia Pista Apo Fosforo & Her Şeyi Yak | Türkiye Şarkıları (Live)','Sezen Aksu','khAfjnma34Q')
# Sezen Aksu - Uçurtma Bayramları
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (280,'Uçurtma Bayramları','Sezen Aksu','zv9fQ5lL9GU')
# Sezen Aksu - İtirafçı Olma (Lyrics I Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (281,'İtirafçı Olma (Lyrics I Şarkı Sözleri)','Sezen Aksu','de8K2udBY4s')
# Sezen Aksu - Aşka Şükrederim (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (282,'Aşka Şükrederim (Official Audio)','Sezen Aksu','40r73LSHDxI')
# Sezen Aksu - Hoşgörü (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (283,'Hoşgörü (Official Audio)','Sezen Aksu','bKMg3OEN3EA')
# Sezen Aksu - Düğün (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (284,'Düğün (Official Audio)','Sezen Aksu','Wly3q5_wvIs')
# Sezen Aksu - Yıllar Sonra (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (285,'Yıllar Sonra (Official Audio)','Sezen Aksu','yyMO1TeBdGo')
# İkinci Bahar
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (286,'İkinci Bahar','Sezen Aksu','cz2opAxkuSQ')
# Sezen Aksu - Günlerimiz (Livaneli 50. Yıl Özel)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (287,'Günlerimiz (Livaneli 50. Yıl Özel)','Sezen Aksu','-7bxzsPYe08')
# Adem Olan Anlar
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (288,'Adem Olan Anlar','Sezen Aksu','WB66QmvDXXA')
# Sezen Aksu - O-kudum-da (Official Audio)
# ...
# Sezen Aksu - En Uzun Gece (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (315,'En Uzun Gece (Official Audio)','Sezen Aksu','QWXNv6IhSx0')
# cebimdeki yabancı Sezen Aksu
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (316,'cebimdeki yabancı Sezen Aksu','Sezen Aksu','rLz3KXw2p-w')
# Sezen Aksu - Beşik (Official Video)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (317,'Beşik (Official Video)','Sezen Aksu','mN2w81pri5c')
# Sezen Aksu -  Menajer (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (318,' Menajer (Official Audio)','Sezen Aksu','oBKdCsaAXDY')
# Sezen Aksu - Yalancı Dünya (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (319,'Yalancı Dünya (Official Audio)','Sezen Aksu','H5q501ot6J4')
# Sezen Aksu - Kırık Vals (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (320,'Kırık Vals (Official Audio)','Sezen Aksu','vOMSSR4H53U')
# Sezen Aksu - Dilimin Ucunda Kelimeler (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (321,'Dilimin Ucunda Kelimeler (Official Audio)','Sezen Aksu','gNk0Q4ESJ0Y')
# Sezen Aksu - Haydi Söyle (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (322,'Haydi Söyle (Official Audio)','Sezen Aksu','XI3JIJO85m4')
# Nuri Harun Ateş & Sezen Aksu - Geçmişe Susmasını Söyle
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (323,'Geçmişe Susmasını Söyle','Nuri Harun Ateş & Sezen Aksu','VmWZT12nfJ8')
# Sezen Aksu - Gamsız (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (324,'Gamsız (Official Audio)','Sezen Aksu','z0BIuBe79-w')
# Sezen Aksu - Işık Doğudan Yükselir (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (325,'Işık Doğudan Yükselir (Official Audio)','Sezen Aksu','-8VXr9yfOmw')
# Sezen Aksu - On:Ay (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (326,'On:Ay (Official Audio)','Sezen Aksu','d3geSj8HKyk')
# 2Pac feat. Sezen Aksu - Adi Menekse ( anX-u mash-up )
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (327,'Adi Menekse ( anX-u mash-up )','2Pac feat. Sezen Aksu','UG1BePfRPs0')
# Sezen Aksu - Strose To Stroma Su | Türkiye Şarkıları  - The Songs of Turkey
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (328,'Strose To Stroma Su | Türkiye Şarkıları ','Sezen Aksu','-Sr7nYYfntg')
# Sezen Aksu - Bazen (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (329,'Bazen (Official Audio)','Sezen Aksu','5Lh6e1F0AGg')
# Sezen Aksu - Olmaz İlaç (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (330,'Olmaz İlaç (Official Audio)','Sezen Aksu','B-84j65SAJw')
# Sezen Aksu - Ayışığı (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (331,'Ayışığı (Official Audio)','Sezen Aksu','eOKWoDpcBPc')
# Sezen Aksu - Çocuk (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (332,'Çocuk (Official Audio)','Sezen Aksu','MedEGuohDCQ')
# Sezen Aksu - Ablam Aşktan Öldü (Lyrics | Şarkı Sözleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (333,'Ablam Aşktan Öldü (Lyrics | Şarkı Sözleri)','Sezen Aksu','uc5I_7a7jmk')
# Sezen Aksu Gelsin - Hayat Bildiğin Gibi
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (334,'Hayat Bildiğin Gibi','Sezen Aksu Gelsin','XgpRxbav8fI')
# Sezen Aksu - Oyalanma (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (335,'Oyalanma (Official Audio)','Sezen Aksu','Gab--ykYSCU')
# Sezan Aksu-Paramparça
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (336,'Sezan Aksu-Paramparça','Sezen Aksu','Aq6fR1RhQ80')
# Sezen Aksu - Geçiyor Bizden De
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (337,'Geçiyor Bizden De','Sezen Aksu','BiloPxEojUM')
# SEZEN ASKU-yüzünü dökme küçük kız
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (338,'SEZEN ASKU-yüzünü dökme küçük kız','Sezen Aksu','jgua3X-PB4k')
# Sezen Aksu - Kapalıyız (Kıvanch K. Mix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (339,'Kapalıyız (Kıvanch K. Mix)','Sezen Aksu','cL8Nq2D6mpg')
# Seni Gidi Vurdumduymaz
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (340,'Seni Gidi Vurdumduymaz','Sezen Aksu','iOJM7Q-SfPM')
# Sezen Aksu - Zelzele (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (341,'Zelzele (Official Audio)','Sezen Aksu','uggPDetFQIY')
# Sezen Aksu - Yanmışım Ben Sönmüşüm Ben (Remix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (342,'Yanmışım Ben Sönmüşüm Ben (Remix)','Sezen Aksu','MAhUzro_obs')
# Sezen Aksu - Zavallı Bir Gece (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (343,'Zavallı Bir Gece (Official Audio)','Sezen Aksu','lcVkuPebVT8')
# Sezen Aksu - Karşı Pencere (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (344,'Karşı Pencere (Official Audio)','Sezen Aksu','vkopQDx5JyY')
# Sezen Aksu - Tebdil-i Mekan (Sharp Boys)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (345,'Tebdil-i Mekan (Sharp Boys)','Sezen Aksu','rESsB4d1gjg')
# Sezen Aksu - Ben Dul Bir Kadınım (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (346,'Ben Dul Bir Kadınım (Official Audio)','Sezen Aksu','eVJmf95pl5M')
# Sezen Aksu - Gözümün Bebeği
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (347,'Gözümün Bebeği','Sezen Aksu','NJWoFqLFz2E')
# Sezen Aksu - Yola Çıkmalı (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (348,'Yola Çıkmalı (Official Audio)','Sezen Aksu','arY2rU4Q_mY')
# Sezen Aksu - Uzun Lafın Kısası (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (349,'Uzun Lafın Kısası (Official Audio)','Sezen Aksu','SmCSrz7zeBQ')
# Sezen Aksu - Neden (2016)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (350,'Neden (2016)','Sezen Aksu','6tvq9_af_vw')
# Batan Gün Kana Benziyor (Canlı)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (351,'Batan Gün Kana Benziyor (Canlı)','Sezen Aksu','YVKNG-_Gmg0')
# Heyamola
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (352,'Heyamola','Sezen Aksu','zKI7cM0Gfuw')
# Sezen Aksu - Kapalıyız (Digital Cut - 2005)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (353,'Kapalıyız (Digital Cut','Sezen Aksu','rB1OHwf_mmw')
# Sezen Aksu - Küçük Yaz Çiçeği (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (354,'Küçük Yaz Çiçeği (Official Audio)','Sezen Aksu','FZtzSuunqb4')
# SEZEN AKSU BEKLEYEYİM DE GÖRELİM
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (355,'SEZEN AKSU BEKLEYEYİM DE GÖRELİM','Sezen Aksu','9c9fDpnXL9Q')
# Kaybolan Yıllar
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (356,'Kaybolan Yıllar','Sezen Aksu','wIqTWWiB254')
# Sezen Aksu - Gözlerindeki Bulut (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (357,'Gözlerindeki Bulut (Official Audio)','Sezen Aksu','DzLxJSJBRPc')
# Sezen Aksu - Deliveren (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (358,'Deliveren (Official Audio)','Sezen Aksu','WJXDC8SFfL8')
# Sezen Aksu - Çocuk ve Dev (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (359,'Çocuk ve Dev (Official Audio)','Sezen Aksu','jS078RJgEUo')
# Git / Geri Dön / Beni Unutma (Canlı)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (360,'Git / Geri Dön / Beni Unutma (Canlı)','Sezen Aksu','4FoXVziOc1w')
# Şıkıdım
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (361,'Şıkıdım','Sezen Aksu','hNYGuGt_1DE')
# Sezen Aksu - Dümtek (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (362,'Dümtek (Official Audio)','Sezen Aksu','d-eH6DWAGOs')
# Sezen Aksu - Tören (Mithat Can Özer & Mustafa Ceceli)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (363,'Tören (Mithat Can Özer & Mustafa Ceceli)','Sezen Aksu','MV-yP4EzGi0')
# Seni Kimler Aldı
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (364,'Seni Kimler Aldı','Sezen Aksu','l7u4F53cWh4')
# Sezen Aksu - Geçen Yaz (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (365,'Geçen Yaz (Official Audio)','Sezen Aksu','mCmnWMNz4bU')
# Sezen Aksu - Unuttun mu Beni (Kivanch K. Remix & Erdinç Erdoğdu Radio Edit)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (366,'Unuttun mu Beni (Kivanch K. Remix & Erdinç Erdoğdu Radio Edit)','Sezen Aksu','8yvK6yl7gbg')
# Onursuz Olmasın Aşk
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (367,'Onursuz Olmasın Aşk','Sezen Aksu','nijAqtfEc-M')
# Ben Sende Tutuklu Kaldım
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (368,'Ben Sende Tutuklu Kaldım','Sezen Aksu','-lX7BdvGdto')
# Sezen Aksu - Leha Dodi (Gel Sevgilim) | Türkiye Şarkıları  - The Songs of Turkey
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (369,'Leha Dodi (Gel Sevgilim) | Türkiye Şarkıları ','Sezen Aksu','wLrxLz0mv2E')
# Sorma
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (370,'Sorma','Sezen Aksu','-nS3VAWNjhE')
# Sezen Aksu - Uzaklarda Bir Çizgide (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (371,'Uzaklarda Bir Çizgide (Official Audio)','Sezen Aksu','z8t4mrbS2rk')
# Kahpe Kader
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (372,'Kahpe Kader','Sezen Aksu','zxgUkUjIVHs')
# Meo - Her Şey Fani (Barış Kula Remix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (373,'Her Şey Fani (Barış Kula Remix)','Meo','fiXK9FinMZg')
# Sezen Aksu - Kardelen (Original Mix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (374,'Kardelen (Original Mix)','Sezen Aksu','gij2hQBEOek')
# Sezen Aksu, Sertab E., Aşkın N. Yengi, Levent Y. - 1 (17.05.2011 - Kral TV Müzik Ödülleri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (375,'1 (17.05.2011','Sezen Aksu, Sertab E., Aşkın N. Yengi, Levent Y.','WHpEaXel_WY')
# Ah Bir Ataş Ver / İzmir'in Kavakları (Canlı)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (376,'Ah Bir Ataş Ver / İzmir in Kavakları (Canlı)','Sezen Aksu','TXEaopsVD6Q')
# Sezen Aksu - İstanbul | Türkiye Şarkıları  - The Songs of Turkey (Live)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (377,'İstanbul | Türkiye Şarkıları ','Sezen Aksu','zZeJysrZqnE')
# Sezen Aksu - Ah Felek Yordun Beni (Kivanch K. Remix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (378,'Ah Felek Yordun Beni (Kivanch K. Remix)','Sezen Aksu','LEBx1ZGK9D0')
# Sezen Aksu - Melankoli
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (379,'Melankoli','Sezen Aksu','LxLTv_jQpJU')
# Sezen Aksu - Ağlama Yar Ağlama | Türkiye Şarkıları  - The Songs of Turkey (Live)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (380,'Ağlama Yar Ağlama | Türkiye Şarkıları ','Sezen Aksu','fonilKqlCyA')
# Sari Gyalin | Türkiye Şarkıları - The Songs of Turkey
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (381,'The Songs of Turkey','Sari Gyalin | Türkiye Şarkıları','5ExP-42rMFE')
# Sezen Aksu   Ud Taksimi
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (382,'Sezen Aksu   Ud Taksimi','Sezen Aksu','ueKH0zPlHbY')
# Sezen Aksu - Arkadaş Şarkısını Duyunca (Emrah Karaduman Mix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (383,'Arkadaş Şarkısını Duyunca (Emrah Karaduman Mix)','Sezen Aksu','2exjkqpsMHQ')
# Sezen Aksu   Alev Alev
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (384,'Sezen Aksu   Alev Alev','Sezen Aksu','NR3BVzAqFv8')
# Sezen Aksu Ft. Suzan Kardeş - Selanik Türküsü - ( Official Audio )
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (385,'Selanik Türküsü','Sezen Aksu Ft. Suzan Kardeş','Fda9BIPWNHI')
# Sezen Aksu - Kardelen 2005 Full Albüm (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (386,'Kardelen 2005 Full Albüm (Official Audio)','Sezen Aksu','MWiSFbJMFnE')
# Sezen Aksu - Güldünya
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (387,'Güldünya','Sezen Aksu','q4APkL3SVTQ')
# Zülfü Livaneli - Sezen Aksu Yiğidim Aslanım (35. Yıl Konseri)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (388,'Sezen Aksu Yiğidim Aslanım (35. Yıl Konseri)','Zülfü Livaneli','0Q2cshjdai4')
# Sezen Aksu - Eskidendi - Can Bener Remix
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (389,'Eskidendi','Sezen Aksu','6-h-vlgWYns')
# Sezen Aksu - La Romansa De Rika Kurtel | Türkiye Şarkıları  - The Songs of Turkey (Live)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (390,'La Romansa De Rika Kurtel | Türkiye Şarkıları ','Sezen Aksu','DDF-p7iJEFY')
# Sezen Aksu "Yeniliğe Doğru & Arkadaş" (Türkiye Şarkıları 2002)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (391,'Sezen Aksu "Yeniliğe Doğru & Arkadaş" (Türkiye Şarkıları 2002)','Sezen Aksu','LeI6Jr5khi8')
# Gomidas | Türkiye Şarkıları - The Songs of Turkey
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (392,'The Songs of Turkey','Gomidas | Türkiye Şarkıları','Gx1qYtzdqYg')
# Sezen Aksu - Bastoniko De Djevezli & Amed Nesim-i Subh-dem | Türkiye Şarkıları
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (393,'Bastoniko De Djevezli & Amed Nesim-i Subh-dem | Türkiye Şarkıları','Sezen Aksu','dTKMIlPdoL8')
# Sude
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (394,'Sude','Sezen Aksu','XRG7mHD_LgM')
# Sezen Aksu - Çamlığın Başında Tüter Bir Tütün - Türkiye Şarkıları (Live)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (395,'Çamlığın Başında Tüter Bir Tütün','Sezen Aksu','cPSZfzXEzJI')
# Sezen Aksu Vay-Okay Barış Versiyon- Bodrum Bianca Beach Konseri
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (396,'Sezen Aksu Vay-Okay Barış Versiyon- Bodrum Bianca Beach Konseri','Sezen Aksu','my2OP-w43tY')
# SEZEN AKSU - BELALIM - REMiX (SüPER)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (397,'BELALIM','SEZEN AKSU','o_JnRR5HJuo')
# Sezen Aksu - Kapalıyız (Official Audio)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (398,'Kapalıyız (Official Audio)','Sezen Aksu','-yL5w3klUFg')
# Sezen Aksu -  Veda 2018
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (399,' Veda 2018','Sezen Aksu','Z5O8pIcVXYk')
# Yara Min | Türkiye Şarkıları  - The Songs of Turkey (Live)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (400,'The Songs of Turkey (Live)','Yara Min | Türkiye Şarkıları ','GhJF6Le7hdo')
# Tenna
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (401,'Tenna','Sezen Aksu','Ly9wpHe7qKI')
# Sezen Aksu - Ballı (Enver Günen Mix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (402,'Ballı (Enver Günen Mix)','Sezen Aksu','NYv-HsOK-Ak')
# Sezen Aksu - Ah Felek Yordun Beni (Okay Barış Remix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (403,'Ah Felek Yordun Beni (Okay Barış Remix)','Sezen Aksu','C8uSCbdzftI')
# To Diko Mu Paploma / Çekin Uşaklar Çekin (Canlı)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (404,'To Diko Mu Paploma / Çekin Uşaklar Çekin (Canlı)','Sezen Aksu','dN8CHdF8f0E')
# Yerevan Erebuni | Türkiye Şarkıları  - The Songs of Turkey (Live)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (405,'The Songs of Turkey (Live)','Yerevan Erebuni | Türkiye Şarkıları ','YADfylyU0MU')
# Sezen Aksu - Kaçırıcam Seni... (Bahadır Tanrıvermiş Mix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (406,'Kaçırıcam Seni... (Bahadır Tanrıvermiş Mix)','Sezen Aksu','NsXwRJH-t8E')
# Dua / Segâh Salât-ı Ümmiye / Segâh Teşrik Tekbiri / Evcârâ Saz Semaîsi / Rast Kar-ı...
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (407,'Dua / Segâh Salât-ı Ümmiye / Segâh Teşrik Tekbiri / Evcârâ Saz Semaîsi / Rast Kar-ı...','Sezen Aksu','aIzqxN7SfQM')
# Nilüfer&Sezen Aksu-Yine Yeni Yeniden (Remix)
# INSERT INTO songs (id,song_name,singer,song_yt_url) VALUES (408,'Nilüfer&Sezen Aksu-Yine Yeni Yeniden (Remix)','Sezen Aksu','UtRAALMeVXQ')

# %%
def mapToJson(songList):
    songJson = {}
    _list = []
    for song in songList:
        songJsonObject = {}
        songJsonObject['id'] = song[0]
        songJsonObject['song_name'] = song[1]
        songJsonObject['singer'] = song[2]
        songJsonObject['song_yt_url'] = song[3]
        _list.append(songJsonObject)
    songJson["songs"] = _list
    return songJson

# %%
def start_service():
    app = Flask(__name__)
    
    CORS(app)
    
    @app.route('/songs', methods=['GET'])
    def getAllSongs():
        query = "SELECT * FROM songs"
        conn = sqlite3.connect('playlist.db')
        cur = conn.cursor()
        cur.execute(query)
        return jsonify(mapToJson(cur.fetchall()))
    
    @app.route('/songs/<int:page>', methods=['GET'])
    def getSongsByPage(page):
        limit = 5
        offset = (page-1)*limit
        query = "SELECT * FROM songs limit {} offset {}".format(limit,offset)
        conn = sqlite3.connect('playlist.db')
        cur = conn.cursor()
        cur.execute(query)
        return jsonify(mapToJson(cur.fetchall()))
    
    @app.route('/song/<songName>', methods=['GET'])
    def getSongByName(songName):
        query = "SELECT * FROM songs WHERE song_name like '%{}%'".format(songName)
        conn = sqlite3.connect('playlist.db')
        cur = conn.cursor()
        cur.execute(query)
        return jsonify(mapToJson(cur.fetchall()))
    
    app.run(host='0.0.0.0', port=5000)

# %%
start_service()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: Do not use the development server in a production environment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [14/Feb/2021 22:04:19] "GET /songs/1 HTTP/1.1" 200 -
# 127.0.0.1 - - [14/Feb/2021 22:04:19] "GET /favicon.ico HTTP/1.1" 404 -

# %%
song_list
# Out:
# ['h0C5TpH-A1I',
#  'p4yxn8ZahPI',
#  'TGHOcyiZrDs',
#  '-aW8x1jTA2U',
#  'Eg6gKLXA30U',
#  'llflkaAP0vQ',
#  '352QSI4nsQk',
#  'fEdZGZpAZZk',
#  'nUhlsec8uhs',
#  'TDoWaCaowMw',
#  'qol0bBbcm44',
#  '2c__lhepTdA',
#  '0-DpSouDHU4',
#  'SpeSzEhpLk8',
#  'uVaG7dvT91s',
#  'UrlQ9AklZT8',
#  '6ywcf07KQZA',
#  'C6_Gtdi32Ek',
#  'mRV8s7YJpCQ',
#  'LYDOlK-wSX0',
#  'H7mxXm0Avts',
#  'ygotTM_4x-g',
#  'rswJ1SiQ8sU',
#  'IVE00F-2ZCw',
#  'g1vCetSh7js',
#  '5k5P_Eqy4xo',
#  'uTSYnM-UxD0',
#  'nm93SFd4TqI',
#  'wRWZeosgFgM',
#  'rzhvo0PF74k',
#  'IRwvyl5aYIc',
#  'O6CIRoPzcws',
#  'TeH7sCVCMJk',
#  'D-i77gTIEWM',
#  'Fhzjkd_LBwU',
#  'vaXrcHa_gYU',
#  'Wuk-PoBRW2E',
#  '3_961n_y4TA',
#  'Lc8Nuk2VN-I',
#  'kR0EX8XK-8I',
#  'vS0oVjcxC_o',
#  'LvNz1IIzPpI',
#  'vjU-RcwSwO4',
#  '9YcwFYrM0JM',
#  'yJVFPENseck',
#  'hy2X6cWi1Is',
#  'N3WhY5mTMXA',
#  'Gx_VRdCgI-c',
#  'C0EgvamXF9c',
#  'm8PyoUy7YLI',
#  'vpc7KnLcgxY',
#  'XTNWD9FeZ20',
#  'VuNrNXQzUuo',
#  'H0e5vRbkhpw',
#  'q92L5xu-xHw',
#  'URdN70OKLLo',
#  '2hPNYeXf-AY',
#  'KWaBVwT5B6g',
#  'EO4r_SV6bbA',
#  'D6r5ZH9YXgE',
#  'qgfLk8Uksxo',
#  'OZ-W9sKJKHg',
#  'FZODxoAwLoc',
#  'NpYvpOKrsUk',
#  'hAfLPFIbi0A',
#  'LkBJja_QdWc',
#  'fkMHS-49ar8',
#  'EsZTne6WEQE',
#  'gQQET1i38KQ',
#  'zNg7PdppImA',
#  'Gi-K-ER823c',
#  'eoOZj7CYmL0',
#  'gQ3E5tDu2t0',
#  '8SadbBESMbM',
#  '-2mcvqv9lCk',
#  'sKqOHTzJATY',
#  'KSlOGG5Ohgg',
#  'lf1MnMGWRlQ',
#  'baVnsJhAcBM',
#  'AXpgWAZHVls',
#  '52shmmb40dM',
#  '7HfrxlYl3cQ',
#  'R0KCc9-0i6E',
#  'DSpQZIwazNc',
#  'CMVtuabMeGc',
#  'QLGs8GL4QaE',
#  'w1t8q6_Ophg',
#  'X6gf7-oS5xU',
#  'VgTZSmjX7P8',
#  'dKVgKwWNSSE',
#  'GVWhtMQvNkc',
#  'vTAEq815Ypg',
#  '-944bPFPRFs',
#  'Q1rH03ijFjY',
#  'mOBNFdggNuE',
#  '1vj5MM9-ncI',
#  'eMKWBksJy1c',
#  '8HWRVPHq_c0',
#  'wJqVkwMkLkk',
#  '0QjiVbksMEU',
#  'Fjx4Enb1w3g',
#  'kRcITnEyRiM',
#  'aMwcXJOA64A',
#  'Y74uukUiCoM',
#  'AyK2mn9L39U',
#  '0O2ft0ZuEHU',
#  'rb9iUUHXsyI',
#  'kYxr7SLY2R0',
#  'yykHOIvO4to',
#  'rG_idC9Tcb4',
#  '1E2AO1BHd3k',
#  'Ky2A1LFIoao',
#  'b4muEWcJxdY',
#  'a2sUqQx1p2A',
#  'Vo6sdlOLHhI',
#  '80yV7JYgoEE',
#  '89PepdEhKCM',
#  'h7g66YD6D8U',
#  'VrMyCnXZYYY',
#  'rNhAHqpp6_g',
#  'mg3v-ll7W6A',
#  'sAsC6Ozru_4',
#  '1EjFP2rBy5Q',
#  'q_gLybnREFM',
#  'e_9IJM3N9XM',
#  'WbFP1bVmEd0',
#  'DCz8WgbndXI',
#  'mXP_rt5KKwA',
#  '-_DMr-dlbXc',
#  'nOM73M0VIQ4',
#  'crw58VTZP2Q',
#  'p0x6nZ27AXw',
#  'lp_w2890n7Q',
#  '1XNjqQILBMw',
#  'Va942t-KCFU',
#  'Pzsg2WSrkmE',
#  '1rIu_6tYC64',
#  'DU21wq1K5XE',
#  'fv5ZRi6WVTw',
#  'Cx40AssrgUo',
#  '4lCC68MiSj4',
#  'iGFRQeb_tiE',
#  'p7MCq0kbntM',
#  'sGbxvhgmbqo',
#  'Yx-7dTQ8uQE',
#  'rK_Rbry0Nuw',
#  'C9rLaC71Yx8',
#  'Jmr0DcR3BV4',
#  '_UNNRcnKGsw',
#  'DgJWuhrv3ZQ',
#  'sXUYCIDsu44',
#  'GZPHbb3_-v4',
#  'QkM8rYjGJl0',
#  'deScooa3lGo',
#  'VZK6CO0RpaM',
#  'GmwkWJgMHvM',
#  'K44eLQi5ocQ',
#  'c1p3Qin-1kM',
#  'X8t7RatOIIs',
#  'B1xAmM7rJnU',
#  'Lv2jX3idgN4',
#  'T1EEG-aw4UY',
#  'ZWy3jShruhU',
#  'fRcGuPFeDeo',
#  'EDumtKX2bxY',
#  'lGx9aWA2fKo',
#  'XrpMf0b_Edc',
#  'efT5n8BVrK4',
#  'B02IfgIgrWc',
#  'wGfV62MPqYg',
#  '1FcarZvvmDw',
#  'jrZ_o8bDqRg',
#  '8bB_4BmLiEs',
#  'EsjOV8hQ7Xo',
#  'T8QPkVxDZWQ',
#  'hQu5exZOPOw',
#  '33YxKtFd2Vo',
#  'hg0RHvNOvRg',
#  'DXmOQuAq2SY',
#  'QOZvjgEsG70',
#  '1XsLm_asa04',
#  'S8VxBxrBaJk',
#  'MaLNAZzfW3w',
#  'hTH0NKpgA7A',
#  'vzmiG_z2_OY',
#  'VphEAUZ2ogY',
#  'iN9GqP0PvNc',
#  'Je0d0X6LGn8',
#  'QsNKvMpoLf0',
#  'ppoVoEXP-RA',
#  'ym5uQOWL2bQ',
#  '2bY1aX3CGIM',
#  'otLYS05byIw',
#  '76SuDqOS8sk',
#  'lZEbKWOZkYw',
#  'FtPosh3y-Hk',
#  'L-zpVXSd7lM',
#  'WXz6jGw0WhQ',
#  'h1gOL8Ywq4A',
#  'lqi0wN6SbzQ',
#  'DxBUrIRvOOc',
#  'eEhBJj-3eDY',
#  'P8MHI67IUcA',
#  'i_wegW9g5KM',
#  'c6W8uYeUQ9k',
#  'rPsujjnRdtI',
#  'sZBM5iDvGZY',
#  'zfwouHFDInQ',
#  'fCX6AFzSUho',
#  'd5EpsNDEAac',
#  'HiXXmP8fXEY',
#  'D2Uro0yaovU',
#  'JnMO4cvuQlM',
#  'TdQqy6RVTV8',
#  'kkMTykQG4Qc',
#  'XoH44MGX7O4',
#  'hVyG4gwLGZc',
#  'f8Mtad-q5Xs',
#  'YNNDarfjuSQ',
#  'R9Dv0MVD7rg',
#  'pqs3dIV_QTk',
#  'GIZWxIuWjmQ',
#  'pMDjDKfGHxU',
#  'dhJqjxKMiyM',
#  'yyJiPpSr8ZY',
#  'KN-nhcPkLd8',
#  'Pj4n6rnBqb4',
#  '9PqARl5l7Q8',
#  'eW1XrsxIkU0',
#  'swWzhJaBtpM',
#  'jPs0g5xHUI0',
#  'evvyOpeTrFw',
#  'zvvaxL7YM5M',
#  '_uRKPlXiF0s',
#  'miSRWD3MSZk',
#  '1TYJNhsqNsc',
#  'HIQXqrHsJvc',
#  '_sY2rlz61-0',
#  'Ga8Stree5kw',
#  'C32ZKPtZYqw',
#  'L9kUxKEK6XY',
#  '3wTVQWH_Yl8',
#  '1xlhoFaFQZY',
#  'nnFJh7MVpnY',
#  'wpFmVYC5qkY',
#  'cxtkpz3TNyY',
#  '0JFIBxtQiQk',
#  'dV5EugpN8Jc',
#  '8lf4v5u7oRU',
#  'IR041JFNrT8',
#  'ifbRuN8OeZw',
#  'nxD-R3YKMy4',
#  'Nxtm1rHi7M0',
#  'TCTNUCXUSV8',
#  'I9x9wjrID7I',
#  'IqaFjKKyQVI',
#  'gv2Q1v8PoPA',
#  '35aDpLmjcq0',
#  'OM_Pl0QhFt4',
#  'Z4oAr4q6FpE',
#  'P-X6Ht5hCc8',
#  'AGK_9trHAHk',
#  'x9hxlB3-Qn4',
#  'Zk7XTI8I9Yc',
#  'NA91QLtvS-k',
#  'gsnJJ2DbqWo',
#  'yW71WhBaXzc',
#  'NVNnEGRLyPI',
#  '7x0-phWAVqI',
#  '1a6hl6OqQkg',
#  '9imBFaWU4vg',
#  'BqdyWu7xl6s',
#  'kiDe5WT4Fa4',
#  'EbNspK9_BlU',
#  'iBIrhiYx23M',
#  'qTOQHvW_pcs',
#  'Z3Roc8TIIp8',
#  'GLxtjX8x3Ro',
#  'khAfjnma34Q',
#  'zv9fQ5lL9GU',
#  'de8K2udBY4s',
#  '40r73LSHDxI',
#  'bKMg3OEN3EA',
#  'Wly3q5_wvIs',
#  'yyMO1TeBdGo',
#  'cz2opAxkuSQ',
#  '-7bxzsPYe08',
#  'WB66QmvDXXA',
#  'FbRNqQIhiow',
#  'PAiRfuFTruE',
#  'kWnjfLnYszw',
#  'QCNyYie57T4',
#  'G7zYre3Lwcs',
#  '6wCT3O9D8WI',
#  'gvUKvRzUM-4',
#  'Tt8dEqjN8n8',
#  'U7cyhM7farg',
#  'AMlmkQruOAI',
#  'Vavao_3B-gI',
#  'bHS16WvqVzE',
#  'URxbWF3aUao',
#  '2k0OCPXY9vo',
#  'db5GoHP663o',
#  'hUKv89E3nMw',
#  '9haX4WlHdzw',
#  'EzMHNytmaYI',
#  '7zEbDoteBR8',
#  'lsZvvDpi4BM',
#  'l8q8aAltiQU',
#  'JCDdNNRPq1o',
#  'OhPzfR0_mfs',
#  'UOV2VNiHbsA',
#  'hHTeTih27Zc',
#  'f_zS-F2a0JE',
#  'QWXNv6IhSx0',
#  'rLz3KXw2p-w',
#  'mN2w81pri5c',
#  'oBKdCsaAXDY',
#  'H5q501ot6J4',
#  'vOMSSR4H53U',
#  'gNk0Q4ESJ0Y',
#  'XI3JIJO85m4',
#  'VmWZT12nfJ8',
#  'z0BIuBe79-w',
#  '-8VXr9yfOmw',
#  'd3geSj8HKyk',
#  'UG1BePfRPs0',
#  '-Sr7nYYfntg',
#  '5Lh6e1F0AGg',
#  'B-84j65SAJw',
#  'eOKWoDpcBPc',
#  'MedEGuohDCQ',
#  'uc5I_7a7jmk',
#  'XgpRxbav8fI',
#  'Gab--ykYSCU',
#  'Aq6fR1RhQ80',
#  'BiloPxEojUM',
#  'jgua3X-PB4k',
#  'cL8Nq2D6mpg',
#  'iOJM7Q-SfPM',
#  'uggPDetFQIY',
#  'MAhUzro_obs',
#  'lcVkuPebVT8',
#  'vkopQDx5JyY',
#  'rESsB4d1gjg',
#  'eVJmf95pl5M',
#  'NJWoFqLFz2E',
#  'arY2rU4Q_mY',
#  'SmCSrz7zeBQ',
#  '6tvq9_af_vw',
#  'YVKNG-_Gmg0',
#  'zKI7cM0Gfuw',
#  'rB1OHwf_mmw',
#  'FZtzSuunqb4',
#  '9c9fDpnXL9Q',
#  'wIqTWWiB254',
#  'DzLxJSJBRPc',
#  'WJXDC8SFfL8',
#  'jS078RJgEUo',
#  '4FoXVziOc1w',
#  'hNYGuGt_1DE',
#  'd-eH6DWAGOs',
#  'MV-yP4EzGi0',
#  'l7u4F53cWh4',
#  'mCmnWMNz4bU',
#  '8yvK6yl7gbg',
#  'nijAqtfEc-M',
#  '-lX7BdvGdto',
#  'wLrxLz0mv2E',
#  '-nS3VAWNjhE',
#  'z8t4mrbS2rk',
#  'zxgUkUjIVHs',
#  'fiXK9FinMZg',
#  'gij2hQBEOek',
#  'WHpEaXel_WY',
#  'TXEaopsVD6Q',
#  'zZeJysrZqnE',
#  'LEBx1ZGK9D0',
#  'LxLTv_jQpJU',
#  'fonilKqlCyA',
#  '5ExP-42rMFE',
#  'ueKH0zPlHbY',
#  '2exjkqpsMHQ',
#  'NR3BVzAqFv8',
#  'Fda9BIPWNHI',
#  'MWiSFbJMFnE',
#  'q4APkL3SVTQ',
#  '0Q2cshjdai4',
#  '6-h-vlgWYns',
#  'DDF-p7iJEFY',
#  'LeI6Jr5khi8',
#  'Gx1qYtzdqYg',
#  'dTKMIlPdoL8',
#  'XRG7mHD_LgM',
#  'cPSZfzXEzJI',
#  'my2OP-w43tY',
#  'o_JnRR5HJuo',
#  '-yL5w3klUFg',
#  'Z5O8pIcVXYk',
#  'GhJF6Le7hdo',
#  'Ly9wpHe7qKI',
#  'NYv-HsOK-Ak',
#  'C8uSCbdzftI',
#  'dN8CHdF8f0E',
#  'YADfylyU0MU',
#  'NsXwRJH-t8E',
#  'aIzqxN7SfQM',
#  'UtRAALMeVXQ']

# %%
for song in songs:
    data = song.find_element_by_tag_name('h3')
    link = data.find_element_by_tag_name('a').get_attribute('href')
    title = data.find_element_by_tag_name('a').get_attribute('title')
    print(title)
    song = link.split("&")[0].split("=")[1]
    index = link.split("&")[2].split("=")[1]
    song_list.append(song)
    query = "INSERT TABLE songs (id,song_name,singer,song_yt_url) VALUES ({},'{}','{}','{}')".format(index,title.split(' - ')[1],title.split(' - ')[0],song)
    print(query)
    break
# Out:
# Sezen Aksu - Yok ki
# INSERT TABLE songs (id,song_name,singer,song_yt_url) VALUES (1,'Yok ki','Sezen Aksu','h0C5TpH-A1I')

# %%
conn.close()
